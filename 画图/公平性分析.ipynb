# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import ast
from pathlib import Path
import seaborn as sns

# 定义自定义顺序
custom_order = ["FedAGSA", "PyramidFL", "FedDocs", "TiFL", "FedAvg"]

# 创建排序键函数
def custom_sort(item):
    # 对于列表中的项目，返回其索引
    for i, prefix in enumerate(custom_order):
        if item.startswith(prefix):
            return i
    # 对于不在列表中的项目，返回一个较大的数，使它们排在最后
    return len(custom_order)

def analyze_client_selection(main_dir, time_info_file, time_bins=None, max_epoch=None, save_plots=True):
    """
    分析联邦学习算法中客户端选择情况，并按时间区间进行统计
    
    参数:
        main_dir (str): 主实验目录路径，包含各个算法子目录
        time_info_file (str): 客户端时间信息文件路径
        time_bins (list): 时间区间列表，例如 [0, 5, 10, 15, 20]，如果为None则自动生成
        max_epoch (int): 要分析的最大epoch数，如果为None则分析所有数据
        save_plots (bool): 是否保存生成的图表
        
    返回:
        dict: 包含各算法分析结果的字典
    """
    print(f"正在分析目录: {main_dir}")
    print(f"使用客户端时间信息文件: {time_info_file}")
    
    # 读取客户端时间信息
    time_info = pd.read_csv(time_info_file)
    time_info = time_info.set_index('client_id')
    
    # 如果未指定时间区间，则自动生成
    if time_bins is None:
        # 根据时间数据的分布自动生成区间
        min_time = time_info['time'].min()
        max_time = time_info['time'].max()
        # 生成5个均匀的区间
        time_bins = np.linspace(min_time, max_time, 6).round(1)
    
    print(f"使用时间区间: {time_bins}")
    
    # 存储分析结果
    results = {}
    
    # 获取算法目录列表并按自定义顺序排序
    algo_dirs = [d for d in os.listdir(main_dir) if os.path.isdir(os.path.join(main_dir, d))]
    algo_dirs.sort(key=custom_sort)
    
    for algo_dir in algo_dirs:
        full_path = os.path.join(main_dir, algo_dir)
        csv_path = os.path.join(full_path, 'epoch_results_with_cumtime.csv')
        
        # 检查CSV文件是否存在
        if not os.path.exists(csv_path):
            print(f"跳过 {algo_dir}: 未找到 epoch_results_with_cumtime.csv 文件")
            continue
        
        try:
            # 读取CSV文件
            df = pd.read_csv(csv_path)
            
            # 确保CSV包含所需列
            if 'selected_clients' not in df.columns:
                print(f"警告: {csv_path} 缺少 selected_clients 列")
                continue
                
            # 限制最大epoch数
            if max_epoch is not None:
                df = df[df['epoch'] <= max_epoch]
                
            # 将字符串形式的列表转换为实际列表
            df['selected_clients'] = df['selected_clients'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
            
            # 统计每个客户端被选择的次数
            client_selections = {}
            for idx, row in df.iterrows():
                selected = row['selected_clients']
                for client in selected:
                    client_selections[client] = client_selections.get(client, 0) + 1
            
            # 创建包含选择次数和时间的DataFrame
            analysis_df = pd.DataFrame({
                'client_id': list(client_selections.keys()),
                'selections': list(client_selections.values())
            })
            
            # 添加时间信息
            analysis_df['time'] = analysis_df['client_id'].map(lambda x: time_info.loc[x, 'time'] if x in time_info.index else np.nan)
            
            # 根据时间区间进行分组统计
            analysis_df['time_bin'] = pd.cut(analysis_df['time'], bins=time_bins)
            bin_stats = analysis_df.groupby('time_bin')['selections'].agg(['mean', 'count', 'std']).round(2)
            
            # 存储算法的分析结果
            results[algo_dir] = {
                'client_selections': client_selections,
                'bin_stats': bin_stats,
                'analysis_df': analysis_df
            }
            
            print(f"成功分析 {algo_dir} 的数据")
            print(f"时间区间统计结果:")
            print(bin_stats)
            
        except Exception as e:
            print(f"处理 {csv_path} 时出错: {e}")
    
    # 如果需要保存图表
    if save_plots and results:
        save_selection_plots(results, main_dir, time_bins)
    
    return results

def save_selection_plots(results, main_dir, time_bins):
    """
    生成并保存客户端选择分析的图表
    
    参数:
        results (dict): analyze_client_selection 函数返回的结果
        main_dir (str): 主实验目录路径
        time_bins (list): 时间区间列表
    """
    # 生成boxplot图表
    plt.figure(figsize=(12, 8))
    
    # 为每个算法准备数据
    plot_data = []
    labels = []
    
    for algo_name, result in results.items():
        df = result['analysis_df']
        plot_data.append(df['selections'])
        algo_short_name = algo_name.split('-')[0]  # 获取算法简短名称
        labels.append(algo_short_name)
    
    # 创建箱线图
    plt.boxplot(plot_data, labels=labels)
    plt.title('客户端选择次数分布', fontsize=16)
    plt.ylabel('选择次数', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    
    # 保存图表
    boxplot_path = os.path.join(main_dir, f'{Path(main_dir).name}_boxplot.png')
    plt.savefig(boxplot_path, dpi=300)
    print(f"保存箱线图: {boxplot_path}")
    
    # 生成轮次时间分布图
    plt.figure(figsize=(12, 8))
    
    # 为每个算法创建数据
    for algo_name, result in results.items():
        df = result['analysis_df']
        algo_short_name = algo_name.split('-')[0]
        
        # 将时间和选择次数相关联
        plt.scatter(df['time'], df['selections'], alpha=0.6, label=algo_short_name)
    
    plt.title('客户端时间与选择次数关系', fontsize=16)
    plt.xlabel('客户端时间', fontsize=14)
    plt.ylabel('选择次数', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=12)
    plt.tight_layout()
    
    # 保存图表
    scatter_path = os.path.join(main_dir, f'{Path(main_dir).name}_roundtime_boxplot.png')
    plt.savefig(scatter_path, dpi=300)
    print(f"保存散点图: {scatter_path}")
    
    # 生成按时间区间的选择次数柱状图
    plt.figure(figsize=(14, 8))
    
    # 计算时间区间标签
    bin_labels = [f"{time_bins[i]}-{time_bins[i+1]}" for i in range(len(time_bins)-1)]
    
    # 为每个算法创建柱状图组
    bar_width = 0.15
    offsets = np.arange(-(len(results) - 1) / 2 * bar_width, (len(results) + 1) / 2 * bar_width, bar_width)
    
    # 为每个时间区间创建一组柱状图
    for i, (algo_name, result) in enumerate(results.items()):
        bin_stats = result['bin_stats']
        means = bin_stats['mean'].values
        
        # 确保数据长度与区间标签一致
        if len(means) < len(bin_labels):
            means = np.pad(means, (0, len(bin_labels) - len(means)), 'constant', constant_values=0)
        
        algo_short_name = algo_name.split('-')[0]
        x = np.arange(len(bin_labels))
        plt.bar(x + offsets[i], means, width=bar_width, label=algo_short_name, alpha=0.7)
    
    plt.title('各时间区间客户端平均选择次数', fontsize=16)
    plt.xlabel('客户端时间区间', fontsize=14)
    plt.ylabel('平均选择次数', fontsize=14)
    plt.xticks(range(len(bin_labels)), bin_labels, rotation=45)
    plt.grid(True, linestyle='--', alpha=0.7, axis='y')
    plt.legend(fontsize=12)
    plt.tight_layout()
    
    # 保存图表
    barplot_path = os.path.join(main_dir, f'{Path(main_dir).name}_relative_roundtime_boxplot.png')
    plt.savefig(barplot_path, dpi=300)
    print(f"保存柱状图: {barplot_path}")
    
    # 生成标准化后的选择次数柱状图
    plt.figure(figsize=(14, 8))
    
    # 为每个算法创建柱状图组
    for i, (algo_name, result) in enumerate(results.items()):
        bin_stats = result['bin_stats']
        means = bin_stats['mean'].values
        counts = bin_stats['count'].values
        
        # 计算总体平均值用于归一化
        total_avg = sum(means * counts) / sum(counts) if sum(counts) > 0 else 1
        
        # 归一化数据
        normalized_means = means / total_avg if total_avg > 0 else means
        
        # 确保数据长度与区间标签一致
        if len(normalized_means) < len(bin_labels):
            normalized_means = np.pad(normalized_means, (0, len(bin_labels) - len(normalized_means)), 'constant', constant_values=0)
        
        algo_short_name = algo_name.split('-')[0]
        x = np.arange(len(bin_labels))
        plt.bar(x + offsets[i], normalized_means, width=bar_width, label=algo_short_name, alpha=0.7)
    
    plt.title('各时间区间客户端选择次数（归一化）', fontsize=16)
    plt.xlabel('客户端时间区间', fontsize=14)
    plt.ylabel('归一化选择次数', fontsize=14)
    plt.xticks(range(len(bin_labels)), bin_labels, rotation=45)
    plt.grid(True, linestyle='--', alpha=0.7, axis='y')
    plt.legend(fontsize=12)
    plt.axhline(y=1.0, color='r', linestyle='--', alpha=0.5)  # 添加参考线
    plt.tight_layout()
    
    # 保存图表
    norm_barplot_path = os.path.join(main_dir, f'{Path(main_dir).name}_normalized_roundtime_boxplot.png')
    plt.savefig(norm_barplot_path, dpi=300)
    print(f"保存归一化柱状图: {norm_barplot_path}")

# # 示例使用方法
# if __name__ == "__main__":
#     # 不直接执行，而是作为库导入使用
#     pass

# %%
import os
# from analyze_client_selection import analyze_client_selection

def main():
    # 主实验目录路径
    main_dir = "/home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.1"
    
    # 客户端时间信息文件路径
    time_info_file = "/home/ypguo/async-FL/src/clients_info/clients_info_2class_cnn_delaymodel.csv"
    
    # 自定义时间区间（可以根据需要修改）
    # 如果不指定，将自动根据数据生成区间
    # time_bins = [0, 3, 6, 9, 12]
    
    # 限制分析的最大epoch数（可选）
    max_epoch = 300
    
    # 执行分析
    results = analyze_client_selection(
        main_dir=main_dir,
        time_info_file=time_info_file,
        # time_bins=time_bins,
        max_epoch=max_epoch,
        save_plots=True
    )
    
    # 输出每个算法的统计信息
    print("\n==== 各算法客户端选择统计 ====")
    for algo_name, result in results.items():
        print(f"\n算法: {algo_name}")
        print("时间区间统计:")
        print(result['bin_stats'])
        
        # 输出额外统计信息
        total_selections = sum(result['client_selections'].values())
        unique_clients = len(result['client_selections'])
        print(f"被选中的独立客户端数: {unique_clients}")
        print(f"客户端总选择次数: {total_selections}")
        print(f"平均每个客户端被选择次数: {total_selections/unique_clients:.2f}")

if __name__ == "__main__":
    main()
# Out:
# 正在分析目录: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.1
# 使用客户端时间信息文件: /home/ypguo/async-FL/src/clients_info/clients_info_2class_cnn_delaymodel.csv
# 使用时间区间: [ 1.2  3.4  5.6  7.7  9.9 12.1]
# 成功分析 FedAGSA-CNN-dir0.1-lm0.01-tg75 的数据
# 时间区间统计结果:
#               mean  count    std
# time_bin
# (1.2, 3.4]   23.95     20   4.59
# (3.4, 5.6]   54.00     18  32.21
# (5.6, 7.7]   40.21     19  26.03
# (7.7, 9.9]   25.17     23   8.08
# (9.9, 12.1]  17.50     20   1.54
# 成功分析 PyramidFL-cnn-dir0.1-plus3 的数据
# 时间区间统计结果:
#               mean  count    std
# time_bin
# (1.2, 3.4]   30.10     20  21.88
# (3.4, 5.6]   32.22     18  27.27
# (5.6, 7.7]   26.26     19  21.23
# (7.7, 9.9]   29.61     23  29.70
# (9.9, 12.1]  30.90     20  18.37
# 成功分析 FedDocs-CNN-dir0.1 的数据
# 时间区间统计结果:
#               mean  count    std
# time_bin
# (1.2, 3.4]   44.50     20  45.47
# (3.4, 5.6]   36.28     18  39.08
# (5.6, 7.7]   30.26     19  32.24
# (7.7, 9.9]   19.22     23   4.77
# (9.9, 12.1]  22.00     20   6.72
# 成功分析 TiFL-CNN-dir0.1 的数据
# 时间区间统计结果:
#               mean  count   std
# time_bin
# (1.2, 3.4]   50.50     20  5.17
# (3.4, 5.6]   28.50     18  4.02
# (5.6, 7.7]   22.21     19  3.36
# (7.7, 9.9]   27.61     23  3.95
# (9.9, 12.1]  21.00     20  3.71
# 成功分析 FedAvg-cnn-dir0.1 的数据
# 时间区间统计结果:
#               mean  count   std
# time_bin
# (1.2, 3.4]   29.30     20  3.80
# (3.4, 5.6]   30.94     18  4.47
# (5.6, 7.7]   28.89     19  5.07
# (7.7, 9.9]   31.52     23  4.52
# (9.9, 12.1]  29.15     20  4.89
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:151: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:155: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# 保存箱线图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.1/Exp2025-FashionMNIST-Dir0.1_boxplot.png
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:174: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:178: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# 保存散点图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.1/Exp2025-FashionMNIST-Dir0.1_roundtime_boxplot.png
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:210: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:214: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# 保存柱状图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.1/Exp2025-FashionMNIST-Dir0.1_relative_roundtime_boxplot.png
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 24402 (\N{CJK UNIFIED IDEOGRAPH-5F52}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:247: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 24402 (\N{CJK UNIFIED IDEOGRAPH-5F52}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_2735889/3335494875.py:251: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# 保存归一化柱状图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.1/Exp2025-FashionMNIST-Dir0.1_normalized_roundtime_boxplot.png
#
# ==== 各算法客户端选择统计 ====
#
# 算法: FedAGSA-CNN-dir0.1-lm0.01-tg75
# 时间区间统计:
#               mean  count    std
# time_bin
# (1.2, 3.4]   23.95     20   4.59
# (3.4, 5.6]   54.00     18  32.21
# (5.6, 7.7]   40.21     19  26.03
# (7.7, 9.9]   25.17     23   8.08
# (9.9, 12.1]  17.50     20   1.54
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3144
# 平均每个客户端被选择次数: 31.44
#
# 算法: PyramidFL-cnn-dir0.1-plus3
# 时间区间统计:
#               mean  count    std
# time_bin
# (1.2, 3.4]   30.10     20  21.88
# (3.4, 5.6]   32.22     18  27.27
# (5.6, 7.7]   26.26     19  21.23
# (7.7, 9.9]   29.61     23  29.70
# (9.9, 12.1]  30.90     20  18.37
# 被选中的独立客户端数: 100
# 客户端总选择次数: 2980
# 平均每个客户端被选择次数: 29.80
#
# 算法: FedDocs-CNN-dir0.1
# 时间区间统计:
#               mean  count    std
# time_bin
# (1.2, 3.4]   44.50     20  45.47
# (3.4, 5.6]   36.28     18  39.08
# (5.6, 7.7]   30.26     19  32.24
# (7.7, 9.9]   19.22     23   4.77
# (9.9, 12.1]  22.00     20   6.72
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
#
# 算法: TiFL-CNN-dir0.1
# 时间区间统计:
#               mean  count   std
# time_bin
# (1.2, 3.4]   50.50     20  5.17
# (3.4, 5.6]   28.50     18  4.02
# (5.6, 7.7]   22.21     19  3.36
# (7.7, 9.9]   27.61     23  3.95
# (9.9, 12.1]  21.00     20  3.71
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
#
# 算法: FedAvg-cnn-dir0.1
# 时间区间统计:
#               mean  count   std
# time_bin
# (1.2, 3.4]   29.30     20  3.80
# (3.4, 5.6]   30.94     18  4.47
# (5.6, 7.7]   28.89     19  5.07
# (7.7, 9.9]   31.52     23  4.52
# (9.9, 12.1]  29.15     20  4.89
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24402 (\N{CJK UNIFIED IDEOGRAPH-5F52}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
# from analyze_client_selection import analyze_client_selection

def main():
    # 主实验目录路径
    main_dir = "/home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.5"
    
    # 客户端时间信息文件路径
    time_info_file = "/home/ypguo/async-FL/src/clients_info/clients_info_2class_cnn_delaymodel.csv"
    
    # 自定义时间区间（可以根据需要修改）
    # 如果不指定，将自动根据数据生成区间
    # time_bins = [0, 3, 6, 9, 12]
    
    # 限制分析的最大epoch数（可选）
    max_epoch = 300
    
    # 执行分析
    results = analyze_client_selection(
        main_dir=main_dir,
        time_info_file=time_info_file,
        # time_bins=time_bins,
        max_epoch=max_epoch,
        save_plots=True
    )
    
    # 输出每个算法的统计信息
    print("\n==== 各算法客户端选择统计 ====")
    for algo_name, result in results.items():
        print(f"\n算法: {algo_name}")
        print("时间区间统计:")
        print(result['bin_stats'])
        
        # 输出额外统计信息
        total_selections = sum(result['client_selections'].values())
        unique_clients = len(result['client_selections'])
        print(f"被选中的独立客户端数: {unique_clients}")
        print(f"客户端总选择次数: {total_selections}")
        print(f"平均每个客户端被选择次数: {total_selections/unique_clients:.2f}")

if __name__ == "__main__":
    main()
# Out:
# 正在分析目录: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.5
# 使用客户端时间信息文件: /home/ypguo/async-FL/src/clients_info/clients_info_2class_cnn_delaymodel.csv
# 使用时间区间: [ 1.2  3.4  5.6  7.7  9.9 12.1]
# 成功分析 FedAGSA-CNN-dir0.5-lm0.01-tg70 的数据
# 时间区间统计结果:
#                mean  count    std
# time_bin
# (1.2, 3.4]   108.25     20  20.88
# (3.4, 5.6]    30.11     18  31.22
# (5.6, 7.7]    10.21     19   3.19
# (7.7, 9.9]    18.65     23   2.44
# (9.9, 12.1]   15.00     20   0.00
# 成功分析 PyramidFL-cnn-dir0.5-timefirst 的数据
# 时间区间统计结果:
#               mean  count    std
# time_bin
# (1.2, 3.4]   26.45     20  18.89
# (3.4, 5.6]   26.83     18  20.09
# (5.6, 7.7]   33.84     19  18.55
# (7.7, 9.9]   35.39     23  16.69
# (9.9, 12.1]  26.55     20  18.50
# 成功分析 PyramidFL-cnn-dir0.5-plus 的数据
# 时间区间统计结果:
#               mean  count    std
# time_bin
# (1.2, 3.4]   17.65     20  47.20
# (3.4, 5.6]   28.44     18  55.63
# (5.6, 7.7]   33.68     19  63.10
# (7.7, 9.9]   36.00     23  61.60
# (9.9, 12.1]  33.35     20  55.98
# 成功分析 FedDocs-CNN-dir0.5 的数据
# 时间区间统计结果:
#               mean  count   std
# time_bin
# (1.2, 3.4]   33.50     20  7.46
# (3.4, 5.6]   27.78     18  6.70
# (5.6, 7.7]   30.16     19  7.63
# (7.7, 9.9]   30.00     23  7.22
# (9.9, 12.1]  28.35     20  5.87
# 成功分析 FedLC-cnn-dir0.5 的数据
# 时间区间统计结果:
#               mean  count   std
# time_bin
# (1.2, 3.4]   29.30     20  3.80
# (3.4, 5.6]   30.94     18  4.47
# (5.6, 7.7]   28.89     19  5.07
# (7.7, 9.9]   31.52     23  4.52
# (9.9, 12.1]  29.15     20  4.89
# 成功分析 FedAvg-cnn-dir0.5 的数据
# 时间区间统计结果:
#               mean  count   std
# time_bin
# (1.2, 3.4]   30.65     20  5.14
# (3.4, 5.6]   29.44     18  4.91
# (5.6, 7.7]   28.79     19  4.86
# (7.7, 9.9]   29.61     23  6.22
# (9.9, 12.1]  31.45     20  6.04
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:151: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:155: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   plt.savefig(boxplot_path, dpi=300)
# 保存箱线图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.5/Exp2025-FashionMNIST-Dir0.5_boxplot.png
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:174: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:178: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from current font.
#   plt.savefig(scatter_path, dpi=300)
# 保存散点图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.5/Exp2025-FashionMNIST-Dir0.5_roundtime_boxplot.png
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:210: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:214: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(barplot_path, dpi=300)
# 保存柱状图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.5/Exp2025-FashionMNIST-Dir0.5_relative_roundtime_boxplot.png
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 24402 (\N{CJK UNIFIED IDEOGRAPH-5F52}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:247: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 24402 (\N{CJK UNIFIED IDEOGRAPH-5F52}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# /tmp/ipykernel_1189170/1935808053.py:251: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.savefig(norm_barplot_path, dpi=300)
# 保存归一化柱状图: /home/ypguo/async-FL/PK/Exp2025-FashionMNIST-Dir0.5/Exp2025-FashionMNIST-Dir0.5_normalized_roundtime_boxplot.png
#
# ==== 各算法客户端选择统计 ====
#
# 算法: FedAGSA-CNN-dir0.5-lm0.01-tg70
# 时间区间统计:
#                mean  count    std
# time_bin
# (1.2, 3.4]   108.25     20  20.88
# (3.4, 5.6]    30.11     18  31.22
# (5.6, 7.7]    10.21     19   3.19
# (7.7, 9.9]    18.65     23   2.44
# (9.9, 12.1]   15.00     20   0.00
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3630
# 平均每个客户端被选择次数: 36.30
#
# 算法: PyramidFL-cnn-dir0.5-timefirst
# 时间区间统计:
#               mean  count    std
# time_bin
# (1.2, 3.4]   26.45     20  18.89
# (3.4, 5.6]   26.83     18  20.09
# (5.6, 7.7]   33.84     19  18.55
# (7.7, 9.9]   35.39     23  16.69
# (9.9, 12.1]  26.55     20  18.50
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
#
# 算法: PyramidFL-cnn-dir0.5-plus
# 时间区间统计:
#               mean  count    std
# time_bin
# (1.2, 3.4]   17.65     20  47.20
# (3.4, 5.6]   28.44     18  55.63
# (5.6, 7.7]   33.68     19  63.10
# (7.7, 9.9]   36.00     23  61.60
# (9.9, 12.1]  33.35     20  55.98
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
#
# 算法: FedDocs-CNN-dir0.5
# 时间区间统计:
#               mean  count   std
# time_bin
# (1.2, 3.4]   33.50     20  7.46
# (3.4, 5.6]   27.78     18  6.70
# (5.6, 7.7]   30.16     19  7.63
# (7.7, 9.9]   30.00     23  7.22
# (9.9, 12.1]  28.35     20  5.87
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
#
# 算法: FedLC-cnn-dir0.5
# 时间区间统计:
#               mean  count   std
# time_bin
# (1.2, 3.4]   29.30     20  3.80
# (3.4, 5.6]   30.94     18  4.47
# (5.6, 7.7]   28.89     19  5.07
# (7.7, 9.9]   31.52     23  4.52
# (9.9, 12.1]  29.15     20  4.89
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
#
# 算法: FedAvg-cnn-dir0.5
# 时间区间统计:
#               mean  count   std
# time_bin
# (1.2, 3.4]   30.65     20  5.14
# (3.4, 5.6]   29.44     18  4.91
# (5.6, 7.7]   28.79     19  4.86
# (7.7, 9.9]   29.61     23  6.22
# (9.9, 12.1]  31.45     20  6.04
# 被选中的独立客户端数: 100
# 客户端总选择次数: 3000
# 平均每个客户端被选择次数: 30.00
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25143 (\N{CJK UNIFIED IDEOGRAPH-6237}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31471 (\N{CJK UNIFIED IDEOGRAPH-7AEF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36873 (\N{CJK UNIFIED IDEOGRAPH-9009}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25321 (\N{CJK UNIFIED IDEOGRAPH-62E9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24402 (\N{CJK UNIFIED IDEOGRAPH-5F52}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ypguo/.conda/envs/leofl/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
