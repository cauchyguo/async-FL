# %%
from paint.drawV2 import *

# %%
custom_order_ablation = ["REHFL", "REHFL-TEHCGA", "REHFL-SAOBA", "REHFL-HAFCS"]
# 使用示例
if __name__ == "__main__":
    # 示例1：使用Savitzky-Golay滤波器平滑并使用Wandb风格显示
    # plot_federated_learning_performance(
    #     main_dir='./PK/Exp2025-V2-FashionMNIST-dir0.5',
    #     max_epoch=2000,
    #     max_time=90000000,
    #     save_dir='./PK/Exp2025-V2-FashionMNIST-dir0.5',
    #     fig_size=(10, 8),
    #     dpi=150,
    #     dataset_name='Cifar10',
    #     dir_alpha=0.1,
    #     smooth_method='savgol',   # 使用Savitzky-Golay滤波器
    #     smooth_params={'window_length': 51, 'polyorder': 3},  # 适合大数据集的窗口参数
    #     wandb_style=True,         # 启用Wandb风格
    #     area_alpha=0.15,          # 区域透明度
    #     fluctuation_window=31     # 波动窗口大小
    # )
    
    # # 示例2：针对分层联邦学习的不同图表使用不同平滑方法
    
    # # 准确率随轮数变化图 - 使用Savitzky-Golay滤波器
    # plot_federated_learning_performance(
    #     main_dir='./PK/Exp2025-V2-FashionMNIST-dir0.5',
    #     max_epoch=2000,
    #     max_time=90000000,
    #     save_dir='./PK/Exp2025-V2-FashionMNIST-dir0.5',
    #     fig_size=(10, 8),
    #     dpi=150,
    #     dataset_name='Cifar10',
    #     dir_alpha=0.1,
    #     smooth_method='savgol',   # 适合保留分层结构的阶梯特征
    #     smooth_params={'window_length': 51, 'polyorder': 3},
    #     wandb_style=True,
    #     area_alpha=0.15,
    #     fluctuation_window=21
    # )
    
    # # 损失值随轮数变化图 - 使用高斯滤波器
    # plot_federated_learning_performance(
    #     main_dir='./PK/Exp2025-V2-FashionMNIST-dir0.5',
    #     max_epoch=2000,
    #     max_time=90000000,
    #     save_dir='./PK/Exp2025-V2-FashionMNIST-dir0.5',
    #     fig_size=(10, 8),
    #     dpi=150,
    #     dataset_name='Cifar10',
    #     dir_alpha=0.1,
    #     smooth_method='gaussian',  # 损失值通常波动较大，使用高斯平滑
    #     smooth_params={'sigma': 5},
    #     wandb_style=True,
    #     area_alpha=0.15,
    #     fluctuation_window=31     # 损失值波动大，使用更大的窗口
    # )
    
    # 准确率随挂钟时间变化图 - 使用指数平滑
    plot_federated_learning_performance(
        main_dir='./Ablation-Exp/FMNIST',
        max_epoch=2000,
        max_time=90000000,
        save_dir='./Ablation-Exp/FMNIST',
        fig_size=(10, 6),
        dpi=150,
        dataset_name='FMNIST',
        dir_alpha=0.1,
        smooth_method='exponential',  # 适合时间不均匀的数据
        smooth_params={'alpha': 0.1},
        wandb_style=True,
        time_fix=[3508.88,3897.63,4102,3675.63],
        # performance_fix=[0.987,None,None,None],
        area_alpha=0.2,
        fluctuation_window=15,
        TTA=[70,75,80],
        last_epochs=20,
        split=False,
        order=custom_order_ablation
    )
# Out:
# 成功加载 REHFL 的数据
# 成功加载 REHFL-TEHCGA 的数据
# 成功加载 REHFL-SAOBA 的数据
# 成功加载 REHFL-HAFCS 的数据
# 结果已保存到 ./Ablation-Exp/FMNIST/FMNIST_0.1_TTA.csv
# 结果已保存到 ./Ablation-Exp/FMNIST/FMNIST_0.1_TTA.csv
# 结果已保存到 ./Ablation-Exp/FMNIST/FMNIST_0.1_TTA.csv
# 结果已保存到 ./Ablation-Exp/FMNIST/FMNIST_0.1_TTA.csv
#           数据集            方法  70%轮次  70%时间(分钟)  75%轮次  75%时间(分钟)  80%轮次  \
# 0  FMNIST_0.1         REHFL    155       4.69    392      11.63    974
# 1  FMNIST_0.1  REHFL-TEHCGA    181       6.26    459      15.21   1090
# 2  FMNIST_0.1   REHFL-SAOBA    146       5.17    484      16.71   1126
# 3  FMNIST_0.1   REHFL-HAFCS    226       7.07    595      18.38   1302
#
#    80%时间(分钟)  总时间(分钟)  最佳准确率
# 0      28.73    58.48  82.87
# 1      35.80    64.96  81.29
# 2      38.51    68.37  81.70
# 3      39.89    61.26  77.63
# 保存图表: ./Ablation-Exp/FMNIST/FMNIST_accuracy_vs_epoch_2000_exponential_a0.1_wandb_style.png
# 保存图表: ./Ablation-Exp/FMNIST/FMNIST_loss_vs_epoch_2000_exponential_a0.1_wandb_style.png
# 保存图表: ./Ablation-Exp/FMNIST/FMNIST_accuracy_vs_time_2000_exponential_a0.1_wandb_style.png
# 绘图完成！
